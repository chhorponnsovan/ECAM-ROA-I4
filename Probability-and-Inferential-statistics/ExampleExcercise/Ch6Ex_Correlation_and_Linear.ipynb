# %%
# !wget -O statisticlib.py https://raw.githubusercontent.com/chhorponnsovan/ECAM-ROA-I4GIM-S2/3dc82178d8c39920cfade3c50ef59a0cfe71d473/Probability-and-Inferential-statistics/ExampleExcercise/statisticlib.py
# Out:
# --2026-05-09 04:12:53--  https://raw.githubusercontent.com/chhorponnsovan/ECAM-ROA-I4GIM-S2/3dc82178d8c39920cfade3c50ef59a0cfe71d473/Probability-and-Inferential-statistics/ExampleExcercise/statisticlib.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3561 (3.5K) [text/plain]
# Saving to: ‘statisticlib.py’
#
# statisticlib.py     100%[===================>]   3.48K  --.-KB/s    in 0s
#
# 2026-05-09 04:12:53 (28.4 MB/s) - ‘statisticlib.py’ saved [3561/3561]

# %% [markdown]
# ![Screenshot_20260509_104258.jpg](data:image/jpeg;base64,...)
